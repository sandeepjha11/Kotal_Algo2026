# %%
import neo_api_client
from neo_api_client import NeoAPI
from datetime import datetime , timedelta
from dateutil.relativedelta import relativedelta
import pandas as pd
pd.set_option('display.max_columns', None)

CK= "mF9TfzZBrA3e9fr4f4pWMY90dT0a"
CS= "vAUzqlgOb4SbcTmIEodhYIVTswEa"
Mob = "+919717263053"
Pwd  = "Noida@304"
MPIN= "650411"

def on_message(message):
    print(message)
    
def on_error(error_message):
    print(error_message)

def on_close(message):
    print(message)
    
def on_open(message):
    print(message)

client = NeoAPI(consumer_key= CK, consumer_secret=CS, environment='PROD',
                access_token=None, neo_fin_key=None)


client.login(mobilenumber=Mob, password=Pwd)
client.session_2fa(OTP=MPIN)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 26
#      23 def on_open(message):
#      24     print(message)
# ---> 26 client = NeoAPI(consumer_key= CK, consumer_secret=CS, environment='PROD',
#      27                 access_token=None, neo_fin_key=None)
#      30 client.login(mobilenumber=Mob, password=Pwd)
#      31 client.session_2fa(OTP=MPIN)
#
# TypeError: NeoAPI.__init__() got an unexpected keyword argument 'consumer_secret'

# %%
# Fyers Login
# Credentials 
redirect_uri = "https://127.0.0.1:5000/"
client_id='LUO95P3YV0-100'
secret_key = '4VHKYVD8J1'

FY_ID = "XS59134"  # Your fyers ID
TOTP_KEY = "XMFF47YV7APTIV7XMCLZIAZHVEEM5KHS"  # TOTP secret is generated when we enable 2Factor TOTP from myaccount portal
PIN = "6504"  # User pin for fyers account


from fyers_apiv3 import fyersModel


"""
In order to get started with Fyers API we would like you to do the following things first.
1. Checkout our API docs :   https://myapi.fyers.in/docsv3
2. Create an APP using our API dashboard :   https://myapi.fyers.in/dashboard/

Once you have created an APP you can start using the below SDK 
"""

#### Generate an authcode and then make a request to generate an accessToken (Login Flow)

                         ## app_secret key which you got after creating the app 
grant_type = "authorization_code"                  ## The grant_type always has to be "authorization_code"
response_type = "code"                             ## The response_type always has to be "code"
state = "sample"                                   ##  The state field here acts as a session manager. you will be sent with the state field after successfull generation of auth_code 


### Connect to the sessionModel object here with the required input parameters
appSession = fyersModel.SessionModel(client_id = client_id, redirect_uri = redirect_uri,response_type=response_type,state=state,secret_key=secret_key,grant_type=grant_type)

# ## Make  a request to generate_authcode object this will return a login url which you need to open in your browser from where you can get the generated auth_code 
generateTokenUrl = appSession.generate_authcode()
generateTokenUrl



from datetime import datetime, timedelta, date
from  time import sleep
import os
import pyotp
import requests
import json
import math
import pytz
from urllib.parse import parse_qs,urlparse
import warnings
import pandas as pd
pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

import base64
def getEncodedString(string):
    string = str(string)
    base64_bytes = base64.b64encode(string.encode("ascii"))
    return base64_bytes.decode("ascii")
  



URL_SEND_LOGIN_OTP="https://api-t2.fyers.in/vagator/v2/send_login_otp_v2"
res = requests.post(url=URL_SEND_LOGIN_OTP, json={"fy_id":getEncodedString(FY_ID),"app_id":"2"}).json()   
print(res) 

if datetime.now().second % 30 > 27 : sleep(5)
URL_VERIFY_OTP="https://api-t2.fyers.in/vagator/v2/verify_otp"
res2 = requests.post(url=URL_VERIFY_OTP, json= {"request_key":res["request_key"],"otp":pyotp.TOTP(TOTP_KEY).now()}).json()  
print(res2) 


ses = requests.Session()
URL_VERIFY_OTP2="https://api-t2.fyers.in/vagator/v2/verify_pin_v2"
payload2 = {"request_key": res2["request_key"],"identity_type":"pin","identifier":getEncodedString(PIN)}
res3 = ses.post(url=URL_VERIFY_OTP2, json= payload2).json()  
print(res3) 


ses.headers.update({
    'authorization': f"Bearer {res3['data']['access_token']}"
})


TOKENURL="https://api-t1.fyers.in/api/v3/token"
payload3 = {"fyers_id":FY_ID,
           "app_id":client_id[:-4],
           "redirect_uri":redirect_uri,
           "appType":"100","code_challenge":"",
           "state":"None","scope":"","nonce":"","response_type":"code","create_cookie":True}

res3 = ses.post(url=TOKENURL, json= payload3).json()  
print(res3)


url = res3['Url']
print(url)
parsed = urlparse(url)
auth_code = parse_qs(parsed.query)['auth_code'][0]
auth_code


grant_type = "authorization_code" 

response_type = "code"  

session = fyersModel.SessionModel(
    client_id=client_id,
    secret_key=secret_key, 
    redirect_uri=redirect_uri, 
    response_type=response_type, 
    grant_type=grant_type
)

# Set the authorization code in the session object
session.set_token(auth_code)

# Generate the access token using the authorization code
response = session.generate_token()

# Print the response, which should contain the access token and other details
#print(response)


access_token = response['access_token']

# Initialize the FyersModel instance with your client_id, access_token, and enable async mode
fyers = fyersModel.FyersModel(client_id=client_id, is_async=False, token=access_token, log_path=os.getcwd())

# Make a request to get the user profile information


# In[ ]:


fyers.get_profile()
# Out:
# {'s': 'ok', 'code': 1043, 'client_name': 'Sandeep Jha', 'nick_name': 'Sandeep', 'pin_created': True, 'totp_enabled': True, 'avatar_link': None, 'message': 'user exist', 'mobile_no': '97xxxxxx53', 'email_id': 'jxxxxxxxxxx1@yahoo.com', 'request_key': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9..fmu4PE3ESP1BNp7mMx3-Skfo1R51DtXOwQfQtE5QjTQ'}
# ...

# %%
from fyers_api import accessToken
from fyers_api import fyersModel
from time import sleep
import pandas as pd
import xlwings as xw
from datetime import datetime, timedelta
import time as tm

# %%
data = {
    "symbol":"NSE:NIFTY50-INDEX",
    "strikecount":1,
    "timestamp": ""
}
optRes = fyers.optionchain(data=data);
optRes
# Out:
# {'code': 200,
#  'data': {'callOi': 131674000,
#   'expiryData': [{'date': '14-08-2024', 'expiry': '1723629600'},
#    {'date': '22-08-2024', 'expiry': '1724320800'},
#    {'date': '29-08-2024', 'expiry': '1724925600'},
#    {'date': '05-09-2024', 'expiry': '1725530400'},
#    {'date': '12-09-2024', 'expiry': '1726135200'},
#    {'date': '26-09-2024', 'expiry': '1727344800'},
#    {'date': '31-10-2024', 'expiry': '1730368800'},
#    {'date': '26-12-2024', 'expiry': '1735207200'},
#    {'date': '27-03-2025', 'expiry': '1743069600'},
#    {'date': '26-06-2025', 'expiry': '1750932000'},
#    {'date': '24-12-2025', 'expiry': '1766570400'},
#    {'date': '25-06-2026', 'expiry': '1782381600'},
#    {'date': '31-12-2026', 'expiry': '1798711200'},
#    {'date': '24-06-2027', 'expiry': '1813831200'},
#    {'date': '30-12-2027', 'expiry': '1830160800'},
#    {'date': '29-06-2028', 'expiry': '1845885600'},
#    {'date': '28-12-2028', 'expiry': '1861610400'},
# ...

# %%
vix = optRes['data']['indiavixData']['ltp']
vix
# Out:
# 15.44

# %%
pcr = optRes['data']['callOi']/optRes['data']['putOi']
pcr
# Out:
# 1.6192702929127565

# %%
optdf = pd.DataFrame(optRes['data']['optionsChain'])
optdf
# Out:
#      ask    bid    description ex_symbol exchange        fp  fpch  fpchp
# 0   0.00   0.00  NIFTY50-INDEX     NIFTY      NSE  24170.45  9.45   0.04  \
# 1   0.05   0.00            NaN       NaN      NaN       NaN   NaN    NaN
# 2  43.75  43.70            NaN       NaN      NaN       NaN   NaN    NaN
# 3   6.25   6.20            NaN       NaN      NaN       NaN   NaN    NaN
# 4   0.05   0.00            NaN       NaN      NaN       NaN   NaN    NaN
# 5  56.45  56.15            NaN       NaN      NaN       NaN   NaN    NaN
# 6   0.05   0.00            NaN       NaN      NaN       NaN   NaN    NaN
#
#            fyToken       ltp  ltpch  ltpchp option_type  strike_price
# 0  101000000026000  24143.75   4.75    0.02                        -1  \
# 1  101124081439649      0.05 -64.85  -99.92          PE         24100
# 2  101124081439639     43.70 -72.15  -62.28          CE         24100
# 3  101124081439652      6.25 -80.60  -92.80          PE         24150
# ...

# %%
spotLtp = optdf[optdf.exchange == 'NSE']['ltp'].iloc[0]
spotLtp
# Out:
# 24143.75

# %%
optdf = optdf[optdf.option_type.isin(['CE','PE'])]
optdf
# Out:
#      ask    bid description ex_symbol exchange  fp  fpch  fpchp
# 1   0.05   0.00         NaN       NaN      NaN NaN   NaN    NaN  \
# 2  43.75  43.70         NaN       NaN      NaN NaN   NaN    NaN
# 3   6.25   6.20         NaN       NaN      NaN NaN   NaN    NaN
# 4   0.05   0.00         NaN       NaN      NaN NaN   NaN    NaN
# 5  56.45  56.15         NaN       NaN      NaN NaN   NaN    NaN
# 6   0.05   0.00         NaN       NaN      NaN NaN   NaN    NaN
#
#            fyToken    ltp  ltpch  ltpchp option_type  strike_price
# 1  101124081439649   0.05 -64.85  -99.92          PE         24100  \
# 2  101124081439639  43.70 -72.15  -62.28          CE         24100
# 3  101124081439652   6.25 -80.60  -92.80          PE         24150
# 4  101124081439650   0.05 -81.90  -99.94          CE         24150
# 5  101124081439655  56.15 -57.60  -50.64          PE         24200
# 6  101124081439653   0.05 -59.90  -99.92          CE         24200
#
# ...

# %%
optdf = optdf.dropna(axis=1, how='all')
optdf
# Out:
#      ask    bid          fyToken    ltp  ltpch  ltpchp option_type
# 1   0.05   0.00  101124081439649   0.05 -64.85  -99.92          PE  \
# 2  43.75  43.70  101124081439639  43.70 -72.15  -62.28          CE
# 3   6.25   6.20  101124081439652   6.25 -80.60  -92.80          PE
# 4   0.05   0.00  101124081439650   0.05 -81.90  -99.94          CE
# 5  56.45  56.15  101124081439655  56.15 -57.60  -50.64          PE
# 6   0.05   0.00  101124081439653   0.05 -59.90  -99.92          CE
#
#    strike_price                 symbol          oi        oich   oichp
# 1         24100  NSE:NIFTY2481424100PE   7851425.0   4372405.0  125.68  \
# 2         24100  NSE:NIFTY2481424100CE   2758025.0    566375.0   25.84
# 3         24150  NSE:NIFTY2481424150PE   9870250.0   7711650.0  357.25
# 4         24150  NSE:NIFTY2481424150CE  16904775.0  14595555.0  632.06
# 5         24200  NSE:NIFTY2481424200PE   2032900.0   -864650.0  -29.84
# ...

# %%
optdf['Strike'] = optdf['strike_price']
del optdf['strike_price'],optdf['fyToken']

optdf
# Out:
#      ask    bid    ltp  ltpch  ltpchp option_type                 symbol
# 1   0.05   0.00   0.05 -64.85  -99.92          PE  NSE:NIFTY2481424100PE  \
# 2  43.75  43.70  43.70 -72.15  -62.28          CE  NSE:NIFTY2481424100CE
# 3   6.25   6.20   6.25 -80.60  -92.80          PE  NSE:NIFTY2481424150PE
# 4   0.05   0.00   0.05 -81.90  -99.94          CE  NSE:NIFTY2481424150CE
# 5  56.45  56.15  56.15 -57.60  -50.64          PE  NSE:NIFTY2481424200PE
# 6   0.05   0.00   0.05 -59.90  -99.92          CE  NSE:NIFTY2481424200CE
#
#            oi        oich   oichp    prev_oi       volume  Strike
# 1   7851425.0   4372405.0  125.68  3479020.0  730969450.0   24100
# 2   2758025.0    566375.0   25.84  2191650.0  284692350.0   24100
# 3   9870250.0   7711650.0  357.25  2158600.0  778516425.0   24150
# 4  16904775.0  14595555.0  632.06  2309220.0  874716550.0   24150
# 5   2032900.0   -864650.0  -29.84  2897550.0  255033625.0   24200
# ...

# %%
cedf = optdf[optdf.option_type == 'CE']
pedf = optdf[optdf.option_type == 'PE']
ocdf = pd.merge(cedf,pedf,on= 'Strike', suffixes = ['_CE', '_PE'])
oscdf = ocdf.sort_values(by = 'Strike')
ocdf
# Out:
#    ask_CE  bid_CE  ltp_CE  ltpch_CE  ltpchp_CE option_type_CE
# 0   43.75    43.7   43.70    -72.15     -62.28             CE  \
# 1    0.05     0.0    0.05    -81.90     -99.94             CE
# 2    0.05     0.0    0.05    -59.90     -99.92             CE
#
#                symbol_CE       oi_CE     oich_CE  oichp_CE  prev_oi_CE
# 0  NSE:NIFTY2481424100CE   2758025.0    566375.0     25.84   2191650.0  \
# 1  NSE:NIFTY2481424150CE  16904775.0  14595555.0    632.06   2309220.0
# 2  NSE:NIFTY2481424200CE  10155675.0   4613195.0     83.23   5542480.0
#
#      volume_CE  Strike  ask_PE  bid_PE  ltp_PE  ltpch_PE  ltpchp_PE
# 0  284692350.0   24100    0.05    0.00    0.05    -64.85     -99.92  \
# 1  874716550.0   24150    6.25    6.20    6.25    -80.60     -92.80
# 2  709238375.0   24200   56.45   56.15   56.15    -57.60     -50.64
#
#   option_type_PE              symbol_PE      oi_PE    oich_PE  oichp_PE
# 0             PE  NSE:NIFTY2481424100PE  7851425.0  4372405.0    125.68  \
# ...

# %%
# Quote of Future

data = {
    "symbols":"NSE:NIFTY24OCTFUT",
}

futureQuotes = fyers.quotes(data=data)
futureQuotes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       1 # Quote of Future
#       3 data = {
#       4     "symbols":"NSE:NIFTY24OCTFUT",
#       5 }
# ----> 7 futureQuotes = fyers.quotes(data=data)
#       8 futureQuotes
#
# NameError: name 'fyers' is not defined

# %%
futureLtp = futureQuotes['d'][0]['v']['lp']
futureLtp
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 futureLtp = futureQuotes['d'][0]['v']['lp']
#       2 futureLtp
#
# KeyError: 'lp'

# %%
import requests
from time import sleep
from datetime import datetime, time
import pandas as pd
import xlwings as xw

wb = xw.Book(r'D:\Share Market\ALGO LEARNING\PYTHON COURSE\Copy_Trade\OptionChain.xlsx')
sheet = wb.sheets['OC']

while datetime.now().time() < time(23,30):
    try:
        data = {
            "symbol":"NSE:NIFTY50-INDEX",
            "strikecount":25,
            "timestamp": ""
        }
        optRes = fyers.optionchain(data=data)

        # Quote of Future

        data = {
            "symbols":"NSE:NIFTY24JULFUT",
            }

        futureQuotes = fyers.quotes(data=data)
        futureLtp = futureQuotes['d'][0]['v']['lp']

        
        vix = optRes['data']['indiavixData']['ltp']
        pcr = optRes['data']['callOi']/optRes['data']['putOi']

        optdf = pd.DataFrame(optRes['data']['optionsChain'])
        spotLtp = optdf[optdf.exchange == 'NSE']['ltp'].iloc[0]
        optdf = optdf[optdf.option_type.isin(['CE','PE'])]
        optdf = optdf.dropna(axis=1, how='all')
        optdf['Strike'] = optdf['strike_price']
        del optdf['strike_price'],optdf['fyToken']
        cedf = optdf[optdf.option_type == 'CE']
        pedf = optdf[optdf.option_type == 'PE']
        ocdf = pd.merge(cedf,pedf,on= 'Strike', suffixes = ['_CE', '_PE'])
        oscdf = ocdf.sort_values(by = 'Strike')
        sheet.clear_contents()
        print(ocdf.head(1))
        sheet['K1'].value = ['Spot','Future','Vix','PCR', 'Premium']
        sheet['K2'].value = [spotLtp,futureLtp,vix,pcr]
        sheet['O2'].value = [futureLtp-spotLtp,]
        sheet['B4'].value = ocdf
    except Exception as e:
        print(f'Error in display {e}')
    sleep(1)

# %%
import neo_api_client
from neo_api_client import NeoAPI
import pandas as pd
import numpy as np
from threading import Thread
import time
import urllib.request
from io import StringIO
import os

# Define the create_exchange_tokens_live function
def create_exchange_tokens_live(df, custom_segment_name):
    exch_tokens = []
    for index, row in df.iterrows():
        token_dict = {
            "instrument_token": str(row['pSymbol']),
            "exchange_segment": custom_segment_name.lower()
        }
        exch_tokens.append(token_dict)
    return exch_tokens

# Define the create_exchange_tokens function
def create_exchange_tokens(data, custom_segment_name):
    exch_tokens = []
    for symbol in data:
        token_dict = {
            "instrument_token": symbol,
            "exchange_segment": custom_segment_name.lower()
        }
        exch_tokens.append(token_dict)
    return exch_tokens

# Define the filter_symbols function
def filter_symbols(df, underlying, expiry_date):
    df['pExpiryDate'] = pd.to_datetime(df['pExpiryDate'])
    expiry_date = pd.to_datetime(expiry_date, format='%Y-%m-%d %H:%M:%S')
    filtered_df = df[
        (df['pTrdSymbol'].str.upper().str.contains(underlying.upper())) &
        (df['pExpiryDate'] == expiry_date)
    ]
    filtered_df.reset_index(drop=True, inplace=True)
    return filtered_df

# Define the on_close function
def on_close(message):
    print('[OnClose]: ', message)

# Define the on_message function
live_data = {}
previous_data = {}

def on_message(message):
    global previous_data, live_data
    try:
        for i in message:
            tk = i.get('tk')
            if tk not in previous_data:
                ltp = float(i.get('ltp'))
                oi = float(i.get('oi'))
                v = float(i.get('v'))
            else:
                ltp = float(i.get('ltp')) if i.get('ltp') is not None else previous_data[tk].get('ltp', 0)
                oi = float(i.get('oi')) if i.get('oi') is not None else previous_data[tk].get('oi', 0)
                v = float(i.get('v')) if i.get('v') is not None else previous_data[tk].get('v', 0)
            live_data[tk] = {'ltp': ltp, 'oi': oi, 'v': v}
            previous_data[tk] = {'ltp': ltp, 'oi': oi, 'v': v}
    except Exception as e:
        print(f"Error in on_message: {e}")

# Define the on_error function
def on_error(message):
    result = message
    print('[OnError]: ', result)

# Load the scrip master data
def load_scrip_master(client):
    fp = client.scrip_master()
    file_paths = fp['filesPaths']
    dfs = []
    for file_path in file_paths:
        with urllib.request.urlopen(file_path) as response:
            content = response.read().decode('utf-8')
            df = pd.read_csv(StringIO(content))
            selected_columns = df[['pSymbol', 'pExchSeg', 'pTrdSymbol', 'pInstType', 'lLotSize', 'pExpiryDate', 'pSegment', 'lFreezeQty']]
            selected_columns.loc[:, 'pExpiryDate'] = pd.to_datetime(selected_columns['pExpiryDate'], unit='s') + pd.DateOffset(years=10)
            dfs.append(selected_columns)
    combined_database = pd.concat(dfs, ignore_index=True)
    return combined_database

# Define the get_tokens_for_quotes function
def get_tokens_for_quotes(security_identifier, combined_database):
    condition = (
        (
            (combined_database['pTrdSymbol'].astype(str).str.strip().str.upper() == security_identifier.strip().upper()) |
            (combined_database['pTrdSymbol'].apply(lambda x: isinstance(x, float) and np.isnan(x)) & pd.isna(security_identifier))
        ) &
        (
            (combined_database['pTrdSymbol'].astype(str).str.strip().str.upper() == security_identifier.strip().upper()) |
            (combined_database['pTrdSymbol'].apply(lambda x: isinstance(x, float) and np.isnan(x)) & pd.isna(security_identifier))
        )
    )
    symbols_info = combined_database[condition][['pSymbol', 'pExchSeg']]
    if symbols_info.empty:
        return []
    symbols_info.reset_index(drop=True, inplace=True)
    symbols_info.rename(columns={'pSymbol': 'instrument_token', 'pExchSeg': 'exchange_segment'}, inplace=True)
    symbols_info['instrument_token'] = "" + symbols_info['instrument_token'].astype(str) + ""
    output_list = symbols_info.to_dict(orient='records')
    return output_list

# Define the stream function
def stream(client, inst_tokens):
    try:
        client.subscribe(instrument_tokens=inst_tokens, isIndex=False, isDepth=False)
    except Exception as e:
        print(f"Error while connecting to the WebSocket: {e}")

# Update live data with trading symbols
def update_live_data_with_symbols(live_data, combined_database):
    symbol_mapping = dict(zip(combined_database['pSymbol'], combined_database['pTrdSymbol']))
    for key, value in live_data.items():
        if key in symbol_mapping:
            value['trading_symbol'] = symbol_mapping[key]
    return live_data

# Write live data to CSV
def write_live_data_to_csv(live_data, file_name):
    live_data_df = pd.DataFrame(live_data).T
    current_dir = os.getcwd()
    file_path = os.path.join(current_dir, file_name)
    live_data_df.to_csv(file_path, index_label='tk')

# Main execution
client = NeoAPI(consumer_key= CK, consumer_secret=CS, environment='PROD',
                access_token=None, neo_fin_key=None)  # Initialize your client here
combined_database = load_scrip_master(client)
tok2 = get_tokens_for_quotes('NIFTY', combined_database)
inst_tokens = tok2
Thread(target=stream, args=(client, inst_tokens)).start()

# Assuming live_data contains data for '26000'
atm = str(round(float(live_data.get('26000', {}).get('ltp', 0)) / 50) * 50)
expiry_date = '24JUL'  # Use 24MAR format for weekly
strike_price = atm
option_type = 'CE'
atm_symbol = f'NIFTY{expiry_date}{strike_price}{option_type}'

original_symbol = atm_symbol
symbol = 'NIFTY'
expiry_date = original_symbol[5:10]
base_strike_price = int(original_symbol[10:15])
option_type = original_symbol[16:]

combined_symbols = []
for i in range(-20, 21):
    ce_strike_price = base_strike_price + i * 50
    ce_symbol = f'{symbol}{expiry_date}{ce_strike_price:05d}CE'
    combined_symbols.append(ce_symbol)
    pe_strike_price = base_strike_price + i * 50
    pe_symbol = f'{symbol}{expiry_date}{pe_strike_price:05d}PE'
    combined_symbols.append(pe_symbol)

filtered_symbols = filter_symbols(combined_database, 'NIFTY', '2024-03-29 14:30:00')
r_df = filtered_symbols[filtered_symbols['pTrdSymbol'].isin(combined_symbols)].copy()
r_df.reset_index(drop=True, inplace=True)

result_tokens = create_exchange_tokens_live(r_df, 'nse_fo')
client.subscribe(instrument_tokens=result_tokens, isIndex=False, isDepth=False)

while True:
    live_data_with_symbols = update_live_data_with_symbols(live_data, combined_database)
    write_live_data_to_csv(live_data_with_symbols, 'live_data.csv')
    time.sleep(0.5)

# %%
def load_scrip_master(client):
    fp = client.scrip_master()
    file_paths = fp['filesPaths']
    dfs = []
    for file_path in file_paths:
        with urllib.request.urlopen(file_path) as response:
            content = response.read().decode('utf-8')
            df = pd.read_csv(StringIO(content))
            selected_columns = df[['pSymbol', 'pExchSeg', 'pTrdSymbol', 'pInstType', 'lLotSize', 'pExpiryDate', 'pSegment', 'lFreezeQty']]
            selected_columns.loc[:, 'pExpiryDate'] = pd.to_datetime(selected_columns['pExpiryDate'], unit='s') + pd.DateOffset(years=10)
            dfs.append(selected_columns)
    combined_database = pd.concat(dfs, ignore_index=True)
    combined_database

# %%
combined_database

# %%
fp = client.scrip_master()
fp['filesPaths']

# %%
url = client.scrip_master()
file_patha = url['filesPaths']

# %%
#you can get this filepaths by running below command
client.scrip_master()
import pandas as pd
import urllib.request
from io import StringIO
file_paths = [
    'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2024-06-08/transformed/bse_cm.csv',
    'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2024-06-08/transformed/cde_fo.csv',
    'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2024-06-08/transformed/mcx_fo.csv',
    'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2024-06-08/transformed/nse_cm.csv',
    'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2024-06-08/transformed/nse_fo.csv',
    'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2024-06-08/transformed/bse_fo.csv'
]
# Initialise an empty list to stor Dataframes
dfs = []

# Download and read each csv file
for file_path in file_paths:
    with urllib.request.urlopen(file_path) as response:
        content = response.read().decode('utf-8')
        df = pd.read_csv(StringIO(content))
        
        # Select specific column
        selected_columns = df[['pSymbol','pExchSeg' ,'pTrdSymbol', 'pInstType', 'lLotSize', 'pExpiryDate', 'pSegment', 'lFreezeQty']]

        #convert expiry date to the desired format
        selected_columns.loc[:, 'pExpiryDate'] = pd.to_datetime(selected_columns['pExpiryDate'], unit = 's') + pd.DateOffset(years=10)
        
        # Append the selected columns Datafram to the list
        dfs.append(selected_columns)
        
        # Comine all Dataframes into a single Dataframe
        combined_database = pd.concat(dfs, ignore_index=True)

# %%
combined_database

# %%
def create_exchange_tokens_live(df, custom_segment_name):
    exch_tokens = []

# %%
inst_tokens = [{"instrument_token": "11536", "exchange_segment": "nse_cm"},
               {"instrument_token": "1594", "exchange_segment": "nse_cm"},
               {"instrument_token": "11915", "exchange_segment": "nse_cm"},
               {"instrument_token": "13245", "exchange_segment": "nse_cm"}]


try:
    # get LTP and Market Depth Data
    client.quotes(instrument_tokens=inst_tokens, quote_type="", isIndex=False)
    
   # OR Quotes API can be accessed without completing login by passing session_token, sid, and server_id
    client.quotes(instrument_tokens = inst_tokens, quote_type="", isIndex=False, session_token="", sid="",server_id="")
except Exception as e:
    print("Exception when calling get Quote api->quotes: %s\n" % e)
# Out:
# [OnError]:  socket is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  'NoneType' object has no attribute 'sock'
# [OnError]:  Connection to remote host was lost.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# ...

# %%
for index, row in df.iterrows():
    # Use the custom_segment_name provided and add it to the end
    token_dict = {
        "instrument_token": str(row['pSymbol']),
        "exchange_segment": NFO.lower()
    }

    exch_tokens.append(token_dict)

return exch_tokens

def create_exchange_tokens(data, custom_segment_name):
    exch_tokens = []

for symbol in data:
    token_dict = {
        "instrument_token": symbol,
        "exchange_segment": NFO.lower()
    }

    exch_tokens.append(token_dict)

return exch_tokens

# %% [markdown]
# ##### from threading import Thread
# import time
#
#
#
# def on_close(message):
#     print('[OnClose]: ', message)
# # Initialize the lock
# from threading import Thread
#
# live_data = {}
#
# # Initialize previous data dictionary
# previous_data = {}
#
#
# def on_message(message):
#     global previous_data, live_data
#     try:
#         #print(f"Received message: {message}")
#         for i in message:
#             tk = i.get('tk')
#
#             # If key doesn't exist in previous_data, default ltp and oi to 0
#             if tk not in previous_data:
#                 ltp = float(i.get('ltp'))
#                 oi = float(i.get('oi'))
#                 v = float(i.get('v'))
#             else:
#                 ltp = float(i.get('ltp')) if i.get('ltp') is not None else previous_data[tk].get('ltp',0)
#                 oi = float(i.get('oi')) if i.get('oi') is not None else previous_data[tk].get('oi',0)
#                 v  = float(i.get('v')) if i.get('v') is not None else previous_data[tk].get('v',0)
#
#             # Update live_data with current values
#             live_data[tk] = {'ltp': ltp, 'oi': oi,'v': v}
#
#             # Update previous_data with current values
#             previous_data[tk] = {'ltp': ltp, 'oi': oi , 'v': v}
#     except Exception as e:
#         print(f"Error in on_message: {e}")
# def on_error(message):
#     result = message
#     print('[OnError]: ', result)

# %%
def filter_symbols(df, underlying, expiry_date):
# Convert 'pExpiryDate' column to datetime format
df['pExpiryDate'] = pd.to_datetime(df['pExpiryDate'])

# Convert the input expiry_date to datetime format
expiry_date = pd.to_datetime(expiry_date, format='%Y-%m-%d %H:%M:%S')

# Filter the DataFrame based on the condition
filtered_df = df[
    (df['pTrdSymbol'].str.upper().str.contains(underlying.upper())) &
    (df['pExpiryDate'] == expiry_date)
]

# Reset the index of the filtered DataFrame
filtered_df.reset_index(drop=True, inplace=True)

return filtered_df

# %%
import pandas as pd
import urllib.request
from io import StringIO

fp = client.scrip_master()
file_paths = fp['filesPaths']
# Initialize an empty list to store DataFrames
dfs = []

# Download and read each CSV file
for file_path in file_paths:
    with urllib.request.urlopen(file_path) as response:
        content = response.read().decode('utf-8')
        df = pd.read_csv(StringIO(content))

        # Select specific columns
        selected_columns = df[['pSymbol','pExchSeg' ,'pTrdSymbol', 'pInstType', 'lLotSize', 'pExpiryDate', 'pSegment', 'lFreezeQty']]

        # Convert 'pExpiryDate' to the desired format
        selected_columns.loc[:, 'pExpiryDate'] = pd.to_datetime(selected_columns['pExpiryDate'], unit='s') + pd.DateOffset(years=10)

        # Append the selected columns DataFrame to the list
        dfs.append(selected_columns)

# Combine all DataFrames into a single DataFrame
combined_database = pd.concat(dfs, ignore_index=True)



import numpy as np
import pandas as pd

def get_tokens_for_quotes(security_identifier, combined_database):
    # Check if the input is a security name or a trading symbol
    condition = (
        (
            (
                (combined_database['pTrdSymbol'].astype(str).str.strip().str.upper() == security_identifier.strip().upper()) |
                (combined_database['pTrdSymbol'].apply(lambda x: isinstance(x, float) and np.isnan(x)) & pd.isna(security_identifier))
            ) &
            (
                (combined_database['pTrdSymbol'].astype(str).str.strip().str.upper() == security_identifier.strip().upper()) |
                (combined_database['pTrdSymbol'].apply(lambda x: isinstance(x, float) and np.isnan(x)) & pd.isna(security_identifier))
            )
        )
    )

    # Filter the DataFrame based on the condition
    symbols_info = combined_database[condition][['pSymbol', 'pExchSeg']]

    if symbols_info.empty:
        return []  # Return an empty list if there are no matching records

    # Reset the index of the filtered DataFrame
    symbols_info.reset_index(drop=True, inplace=True)

    # Rename the columns
    symbols_info.rename(columns={'pSymbol': 'instrument_token', 'pExchSeg': 'exchange_segment'}, inplace=True)

    # Ensure that instrument_token values are enclosed in single quotes
    symbols_info['instrument_token'] = "" + symbols_info['instrument_token'].astype(str) + ""

    # Create a list of dictionaries in the desired format
    output_list = symbols_info.to_dict(orient='records')

    return output_list

# %%
tok2=get_tokens_for_quotes('NIFTY', combined_database)

inst_tokens = tok2


def stream():
    try:
        client.subscribe(instrument_tokens=inst_tokens, isIndex=False, isDepth=False)
    except Exception as e:
        print(f"Error while connecting to the WebSocket: {e}")

# Assuming you have a properly initialized `client` object elsewhere
Thread(target=stream).start()

# %%
atm = str(round(float(live_data['26000']['ltp'])/50)* 50)

expiry_date = '24MAR' #use 24321 format for weekly
strike_price = atm
option_type = 'CE'
atm_symbol = f'NIFTY{expiry_date}{strike_price}{option_type}'
atm_symbol

original_symbol = atm_symbol

symbol = 'NIFTY'
# Extracting information from the original symbol
expiry_date = original_symbol[5:10]
base_strike_price = int(original_symbol[10:15])
option_type = original_symbol[16:]

# Creating new symbols with a gap of 50 for CE (Call)
combined_symbols = []

for i in range(-20, 21):
    # Creating new symbols with a gap of 50 for CE (Call)
    ce_strike_price = base_strike_price + i * 50
    ce_symbol = f'{symbol}{expiry_date}{ce_strike_price:05d}CE'
    combined_symbols.append(ce_symbol)

    # Creating new symbols with a gap of 50 for PE (Put)
    pe_strike_price = base_strike_price + i * 50
    pe_symbol = f'{symbol}{expiry_date}{pe_strike_price:05d}PE'
    combined_symbols.append(pe_symbol)

symbol_data = combined_database
filtered_symbols = filter_symbols(symbol_data, 'NIFTY', '2024-03-29 14:30:00')
print(filtered_symbols)
r_df = filtered_symbols[filtered_symbols['pTrdSymbol'].isin(combined_symbols)].copy()

# Reset the index of the result DataFrame
r_df.reset_index(drop=True, inplace=True)


result_tokens = create_exchange_tokens_live(r_df, 'nse_fo')

# %%
client.subscribe(instrument_tokens=result_tokens, isIndex=False, isDepth=False)

# %%
import requests
import pandas as pd
import xlwings as xw
import json 
import time 
import openpyxl


exp_date = '09-NOV-2024'

file = xw.Book("Data.xlsx")
sh1 = file.sheets("Nifty50")
sh2 = file.sheets("ND")
sym = "NIFTY"


def oc(sym,exp_date ):
     url = "https://www.nseindia.com/api/option-chain-indices?symbol="+sym
     headers = {"accept-encoding":"gzip, deflate, br",
                "accept-language":"en-US,en;q=0.9",
                "referer": "https://www.nseindia.com/get-quotes/derivatives?symbol="+sym,
                "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) ApplelebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36 Edg/105.0.1343.33"}


     response = requests.get(url, headers = headers).text

     data = json.loads(response)

     exp_list = data['records']['expiryDates']

     ce = {}
     pe = {}
     n = 0
     m = 0

     for i in data['records']['data'] :
         
             try:
                 ce[n] = i['CE']
                 n = n+1
             except:
                 pass
             try:
                 pe[m] = i['PE']
                 m = m+1
             except:
                 pass 


     ce_df = pd.DataFrame.from_dict(ce).transpose()
     ce_df.columns += "_CE" 
     pe_df = pd.DataFrame.from_dict(pe).transpose()
     pe_df.columns += "_PE"        

     df = pd.concat([ce_df, pe_df], axis = 1)

     return exp_list, df

while True:
     try:
          data = oc(sym,exp_date)
          sh1.range("A5").value = data[1]
          sh2.range("A1").options(transpose = True).value = data[0]
          time.sleep(60)
     except:
         print("Retrying")      
         time.sleep(1)

# %%
import neo_api_client
from neo_api_client import NeoAPI
from datetime import datetime , timedelta
from dateutil.relativedelta import relativedelta
import pandas as pd
pd.set_option('display.max_columns', None)

CK= "mF9TfzZBrA3e9fr4f4pWMY90dT0a"
CS= "vAUzqlgOb4SbcTmIEodhYIVTswEa"
Mob = "+919717263053"
Pwd  = "Noida@304"
MPIN= "650411"

def on_message(message):
    print(message)
    
def on_error(error_message):
    print(error_message)

def on_close(message):
    print(message)
    
def on_open(message):
    print(message)


client = NeoAPI(consumer_key= CK, consumer_secret=CS, environment='PROD',
                access_token=None, neo_fin_key=None)


client.login(mobilenumber=Mob, password=Pwd)
client.session_2fa(OTP=MPIN)


# Fyers Login
# Credentials 
redirect_uri = "https://127.0.0.1:5000/"
client_id='LUO95P3YV0-100'
secret_key = '4VHKYVD8J1'

FY_ID = "XS59134"  # Your fyers ID
TOTP_KEY = "XMFF47YV7APTIV7XMCLZIAZHVEEM5KHS"  # TOTP secret is generated when we enable 2Factor TOTP from myaccount portal
PIN = "6504"  # User pin for fyers account


from fyers_apiv3 import fyersModel


"""
In order to get started with Fyers API we would like you to do the following things first.
1. Checkout our API docs :   https://myapi.fyers.in/docsv3
2. Create an APP using our API dashboard :   https://myapi.fyers.in/dashboard/

Once you have created an APP you can start using the below SDK 
"""

#### Generate an authcode and then make a request to generate an accessToken (Login Flow)

                         ## app_secret key which you got after creating the app 
grant_type = "authorization_code"                  ## The grant_type always has to be "authorization_code"
response_type = "code"                             ## The response_type always has to be "code"
state = "sample"                                   ##  The state field here acts as a session manager. you will be sent with the state field after successfull generation of auth_code 


### Connect to the sessionModel object here with the required input parameters
appSession = fyersModel.SessionModel(client_id = client_id, redirect_uri = redirect_uri,response_type=response_type,state=state,secret_key=secret_key,grant_type=grant_type)

# ## Make  a request to generate_authcode object this will return a login url which you need to open in your browser from where you can get the generated auth_code 
generateTokenUrl = appSession.generate_authcode()
generateTokenUrl



from datetime import datetime, timedelta, date
from  time import sleep
import os
import pyotp
import requests
import json
import math
import pytz
from urllib.parse import parse_qs,urlparse
import warnings
import pandas as pd
pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')

import base64
def getEncodedString(string):
    string = str(string)
    base64_bytes = base64.b64encode(string.encode("ascii"))
    return base64_bytes.decode("ascii")
  



URL_SEND_LOGIN_OTP="https://api-t2.fyers.in/vagator/v2/send_login_otp_v2"
res = requests.post(url=URL_SEND_LOGIN_OTP, json={"fy_id":getEncodedString(FY_ID),"app_id":"2"}).json()   
print(res) 

if datetime.now().second % 30 > 27 : sleep(5)
URL_VERIFY_OTP="https://api-t2.fyers.in/vagator/v2/verify_otp"
res2 = requests.post(url=URL_VERIFY_OTP, json= {"request_key":res["request_key"],"otp":pyotp.TOTP(TOTP_KEY).now()}).json()  
print(res2) 


ses = requests.Session()
URL_VERIFY_OTP2="https://api-t2.fyers.in/vagator/v2/verify_pin_v2"
payload2 = {"request_key": res2["request_key"],"identity_type":"pin","identifier":getEncodedString(PIN)}
res3 = ses.post(url=URL_VERIFY_OTP2, json= payload2).json()  
print(res3) 


ses.headers.update({
    'authorization': f"Bearer {res3['data']['access_token']}"
})


TOKENURL="https://api-t1.fyers.in/api/v3/token"
payload3 = {"fyers_id":FY_ID,
           "app_id":client_id[:-4],
           "redirect_uri":redirect_uri,
           "appType":"100","code_challenge":"",
           "state":"None","scope":"","nonce":"","response_type":"code","create_cookie":True}

res3 = ses.post(url=TOKENURL, json= payload3).json()  
print(res3)


url = res3['Url']
print(url)
parsed = urlparse(url)
auth_code = parse_qs(parsed.query)['auth_code'][0]
auth_code


grant_type = "authorization_code" 

response_type = "code"  

session = fyersModel.SessionModel(
    client_id=client_id,
    secret_key=secret_key, 
    redirect_uri=redirect_uri, 
    response_type=response_type, 
    grant_type=grant_type
)

# Set the authorization code in the session object
session.set_token(auth_code)

# Generate the access token using the authorization code
response = session.generate_token()

# Print the response, which should contain the access token and other details
#print(response)


access_token = response['access_token']

# Initialize the FyersModel instance with your client_id, access_token, and enable async mode
fyers = fyersModel.FyersModel(client_id=client_id, is_async=False, token=access_token, log_path=os.getcwd())

# Make a request to get the user profile information


# In[ ]:


fyers.get_profile()


import requests
from time import sleep
from datetime import datetime, time
import pandas as pd
import xlwings as xw

wb = xw.Book(r'D:\Share Market\ALGO LEARNING\PYTHON COURSE\Copy_Trade\OptionChain_BACKUP.xlsx')
sheet = wb.sheets['rawdata']
sheetOC = wb.sheets['OC']
while datetime.now().time() < time(23,30):
    try:
        data = {
            "symbol":"NSE:NIFTY50-INDEX",
            "strikecount":25,
            "timestamp": ""
        }
        optRes = fyers.optionchain(data=data)


        # Opening Price of Spot
        data = {
            "symbols":"NSE:NIFTY50-INDEX"
        }

        spotqt = fyers.quotes(data=data)
        spotop = spotqt['d'][0]['v']['open_price']
        
        # Quote of Future

        fut = sheetOC.range("A1").value
        data = {
            "symbols":'NSE:NIFTY24SEPFUT',
            }

        futureQuotes = fyers.quotes(data=data)
        futureLtp = futureQuotes['d'][0]['v']['lp']

        
        vix = optRes['data']['indiavixData']['ltp']
        pcr = optRes['data']['callOi']/optRes['data']['putOi']

        optdf = pd.DataFrame(optRes['data']['optionsChain'])
        spotLtp = optdf[optdf.exchange == 'NSE']['ltp'].iloc[0]
        optdf = optdf[optdf.option_type.isin(['CE','PE'])]
        optdf = optdf.dropna(axis=1, how='all')
        optdf['Strike'] = optdf['strike_price']
        del optdf['strike_price'],optdf['fyToken']
        cedf = optdf[optdf.option_type == 'CE']
        pedf = optdf[optdf.option_type == 'PE']
        ocdf = pd.merge(cedf,pedf,on= 'Strike', suffixes = ['_CE', '_PE'])
        oscdf = ocdf.sort_values(by = 'Strike')
        sheet.clear_contents()
        print(ocdf.head(1))
        sheet['K1'].value = ['Spot','Future','Vix','PCR','Opening_Price','Premium',]
        sheet['K2'].value = [spotLtp,futureLtp,vix,pcr,spotop]
        sheet['P2'].value = [futureLtp-spotLtp,]
        sheet['B4'].value = ocdf
    except Exception as e:
        print(f'Error in display {e}')
    sleep(.1)
# Out:
# {"data": {"access_token": "eyJ4NXQiOiJNbUprWWpVMlpETmpNelpqTURBM05UZ3pObUUxTm1NNU1qTXpNR1kyWm1OaFpHUTFNakE1TmciLCJraWQiOiJaalJqTUdRek9URmhPV1EwTm1WallXWTNZemRtWkdOa1pUUmpaVEUxTlRnMFkyWTBZVEUyTlRCaVlURTRNak5tWkRVeE5qZ3pPVGM0TWpGbFkyWXpOUV9SUzI1NiIsImFsZyI6IlJTMjU2In0..a5rzB2N54ffvSCbpNDFIjhEdJTrnAOuMhmj8dayb0IW0wYGxB-qitsMI27Qx5cSN15Eci0zTlpdZf2WONBGaRXkj--5LmCY5DeK5eBvDFrBGzSceKW6o1iNysKIpRfOIjJsFIXMob74YtjcTE8Lt1-v1KhzC82leHdrsngvM7IOtCoZeTTAQy8zn6BK7D59eL69-geBHkHntTaIxSqriEYDnNb0kqQTHKhXksGgN1jRy4sZ2qpb_c24hwP2pNm-2WOGHgoIIB9_eGXrXTvXvrQUh5w7puwv_nlaY98AcbzdW8FGfSExNW7kIO3WZIoMIEELWjYVWFUhTc8kmw2
# ...

# %%
spotLtp = optdf[optdf.exchange == 'NSE']
spotLtp

# %%
data = {
    "symbols":"NSE:NIFTY50-INDEX"
}

spotqt = fyers.quotes(data=data)
spotop = spotqt['d'][0]['v']['open_price']
spotop
#spotqt

# %%
data = {
            "symbols":"NSE:NIFTY24AUGFUT",
            }
futureQuotes = fyers.quotes(data=data)
futureLtp = futureQuotes['d'][0]['v']['lp']
futureLtp

# %%
import datetime as dt
wb = xw.Book('OptionChain_BACKUP.xlsx')
sheet = wb.sheets['Sheet1']
sheet['A1'].value = 1
sheet['A1'].value
sheet['A2'].value = 'Hello'
sheet['A2'].value
sheet['A3'].value is None
sheet['A4'].value = dt.datetime(12,1,23)
sheet['A4'].value

# %%
val = sheet.range("E1").value 
sheet['D5'].value = val
print("A value in sheet1 :", val)

# %%
# Quote of Future

fut = sheet.range("E1").value
data = {
    "symbols":fut,
}

futureQuotes = fyers.quotes(data=data)
futureQuotes
futureLtp = futureQuotes['d'][0]['v']['lp']
futureLtp

# %%
data = {
    "symbol":"NSE:NIFTY50-INDEX",
    "strikecount":1,
    "timestamp": ""
}
optRes = fyers.optionchain(data=data);
optRes

# %%
optdf = pd.DataFrame(optRes['data']['expiryData'])
optdf

# %%
sheet['D5'].value = optdf

# %%
from neo_api_client import NeoAPI

def on_message(message):
    print('[Res]: ', message)


def on_error(message):
    result = message
    print('[OnError]: ', result)


# Setup Callbacks for websocket events (Optional)
client.on_message = on_message  # called when message is received from websocket
client.on_error = on_error  # called when any error or exception occurs in code or websocket
client.on_close = None  # called when websocket connection is closed
client.on_open = None  # called when websocket successfully connects

inst_tokens = [{"instrument_token": "11536", "exchange_segment": "nse_cm"},
               {"instrument_token": "1594", "exchange_segment": "nse_cm"},
               {"instrument_token": "11915", "exchange_segment": "nse_cm"},
               {"instrument_token": "13245", "exchange_segment": "nse_cm"}]

try:
    # get LTP and Market Depth Data
    client.quotes(instrument_tokens=inst_tokens, quote_type="", isIndex=False)
    
   # OR Quotes API can be accessed without completing login by passing session_token, sid, and server_id
    client.quotes(instrument_tokens = inst_tokens, quote_type="", isIndex=False, session_token="", sid="",server_id="")
except Exception as e:
    print("Exception when calling get Quote api->quotes: %s\n" % e)
# Out:
# Warning!
# on_close callback is not Set
# on_open callback is not Set
# It is recommended to set callbacks to handle your own logic on events.
# [OnError]:  socket is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  'NoneType' object has no attribute 'sock'
# [OnError]:  Connection to remote host was lost.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# [OnError]:  Connection is already closed.
# ...

# %%
try:
    # Ensure `instrument_tokens` is passed as a list
    response = client.quotes(
        instrument_tokens=[11536],  # Pass the instrument token inside a list
        quote_type="", 
        isIndex=False, 
        session_token="your_session_token",  # Provide a valid session token
        sid="your_sid",                      # Provide a valid SID if needed
        server_id="your_server_id"           # Provide the correct server ID if necessary
    )
    print(response)  # Print or process the response from the API

except Exception as e:
    # Catch and print any exception
    print(f"Exception when calling get Quote API->quotes: {e}\n")
# Out:
# Exception when calling get Quote API->quotes: 'int' object has no attribute 'keys'
